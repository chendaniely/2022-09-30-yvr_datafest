# %%
import pandas

# %%
pandas.__version__
# Out:
# '1.4.2'

# %%
pandas.read_csv("data/gapminder.tsv", sep="\t")
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
import pandas as pd

# %%
pd.read_csv("data/gapminder.tsv", sep="\t")
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
dat = pd.read_csv("data/gapminder.tsv", sep="\t")

# %%
dat
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
type(dat)
# Out:
# pandas.core.frame.DataFrame

# %%
dat.shape
# Out:
# (1704, 6)

# %%
dat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
dat.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 dat.shape()
#
# TypeError: 'tuple' object is not callable

# %%
dat.info
# Out:
# <bound method DataFrame.info of           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]>

# %%
dat.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
dat.tail()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1699  Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
dat.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
dat.index
# Out:
# RangeIndex(start=0, stop=1704, step=1)

# %%
dat.values
# Out:
# array([['Afghanistan', 'Asia', 1952, 28.801, 8425333, 779.4453145],
#        ['Afghanistan', 'Asia', 1957, 30.332, 9240934, 820.8530296],
#        ['Afghanistan', 'Asia', 1962, 31.997, 10267083, 853.10071],
#        ...,
#        ['Zimbabwe', 'Africa', 1997, 46.809, 11404948, 792.4499603],
#        ['Zimbabwe', 'Africa', 2002, 39.989, 11926563, 672.0386227],
#        ['Zimbabwe', 'Africa', 2007, 43.487, 12311143, 469.7092981]],
#       dtype=object)

# %%
dat["country"]
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
type(dat["country"])
# Out:
# pandas.core.series.Series

# %%
dat[["country", "year"]]
# Out:
#           country  year
# 0     Afghanistan  1952
# 1     Afghanistan  1957
# 2     Afghanistan  1962
# 3     Afghanistan  1967
# 4     Afghanistan  1972
# ...           ...   ...
# 1699     Zimbabwe  1987
# 1700     Zimbabwe  1992
# 1701     Zimbabwe  1997
# 1702     Zimbabwe  2002
# 1703     Zimbabwe  2007
#
# [1704 rows x 2 columns]

# %%
dat
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
dat.loc[0]
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap     779.445314
# Name: 0, dtype: object

# %%
dat.loc[1703]
# Out:
# country        Zimbabwe
# continent        Africa
# year               2007
# lifeExp          43.487
# pop            12311143
# gdpPercap    469.709298
# Name: 1703, dtype: object

# %%
dat.loc[-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.pyenv/versions/3.9.11/envs/ds/lib/python3.9/site-packages/pandas/core/indexes/range.py:385, in RangeIndex.get_loc(self, key, method, tolerance)
#     384 try:
# --> 385     return self._range.index(new_key)
#     386 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [27], in <cell line: 1>()
# ----> 1 dat.loc[-1]
#
# File ~/.pyenv/versions/3.9.11/envs/ds/lib/python3.9/site-packages/pandas/core/indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# ...

# %%
dat.iloc[-1]
# Out:
# country        Zimbabwe
# continent        Africa
# year               2007
# lifeExp          43.487
# pop            12311143
# gdpPercap    469.709298
# Name: 1703, dtype: object

# %%
dat.loc[:, ["year", "pop"]]
# Out:
#       year       pop
# 0     1952   8425333
# 1     1957   9240934
# 2     1962  10267083
# 3     1967  11537966
# 4     1972  13079460
# ...    ...       ...
# 1699  1987   9216418
# 1700  1992  10704340
# 1701  1997  11404948
# 1702  2002  11926563
# 1703  2007  12311143
#
# [1704 rows x 2 columns]

# %%
dat.loc[[0, 100,  1700], ["year", "pop"]]
# Out:
#       year       pop
# 0     1952   8425333
# 100   1972  70759295
# 1700  1992  10704340

# %%
dat.loc[, ]

# %%
dat["country"] == "Zimbabwe"
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1699     True
# 1700     True
# 1701     True
# 1702     True
# 1703     True
# Name: country, Length: 1704, dtype: bool

# %%
dat.loc[dat["country"] == "Canada", :]
# Out:
#     country continent  year  lifeExp       pop    gdpPercap
# 240  Canada  Americas  1952   68.750  14785584  11367.16112
# 241  Canada  Americas  1957   69.960  17010154  12489.95006
# 242  Canada  Americas  1962   71.300  18985849  13462.48555
# 243  Canada  Americas  1967   72.130  20819767  16076.58803
# 244  Canada  Americas  1972   72.880  22284500  18970.57086
# 245  Canada  Americas  1977   74.210  23796400  22090.88306
# 246  Canada  Americas  1982   75.760  25201900  22898.79214
# 247  Canada  Americas  1987   76.860  26549700  26626.51503
# 248  Canada  Americas  1992   77.950  28523502  26342.88426
# 249  Canada  Americas  1997   78.610  30305843  28954.92589
# 250  Canada  Americas  2002   79.770  31902268  33328.96507
# 251  Canada  Americas  2007   80.653  33390141  36319.23501

# %%
dat.loc[(dat["country"] == "Canada") & (dat["year"] > 1990), :]
# Out:
#     country continent  year  lifeExp       pop    gdpPercap
# 248  Canada  Americas  1992   77.950  28523502  26342.88426
# 249  Canada  Americas  1997   78.610  30305843  28954.92589
# 250  Canada  Americas  2002   79.770  31902268  33328.96507
# 251  Canada  Americas  2007   80.653  33390141  36319.23501

# %%
dat.loc[(dat["country"] == "Canada") & (dat["year"] > 1990), ["country", "year", "lifeExp"]]
# Out:
#     country  year  lifeExp
# 248  Canada  1992   77.950
# 249  Canada  1997   78.610
# 250  Canada  2002   79.770
# 251  Canada  2007   80.653

# %%
canada_1990 = dat.loc[(dat["country"] == "Canada") & (dat["year"] > 1990), ["country", "year", "lifeExp"]]

# %%
canada_1990
# Out:
#     country  year  lifeExp
# 248  Canada  1992   77.950
# 249  Canada  1997   78.610
# 250  Canada  2002   79.770
# 251  Canada  2007   80.653

# %%
dat.groupby("year")["lifeExp"].mean()
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
dat.groupby(["year", "continent"])["lifeExp"].mean()
# Out:
# year  continent
# 1952  Africa       39.135500
#       Americas     53.279840
#       Asia         46.314394
#       Europe       64.408500
#       Oceania      69.255000
# 1957  Africa       41.266346
#       Americas     55.960280
#       Asia         49.318544
#       Europe       66.703067
#       Oceania      70.295000
# 1962  Africa       43.319442
#       Americas     58.398760
#       Asia         51.563223
#       Europe       68.539233
#       Oceania      71.085000
# 1967  Africa       45.334538
#       Americas     60.410920
#       Asia         54.663640
#       Europe       69.737600
#       Oceania      71.310000
# 1972  Africa       47.450942
#       Americas     62.394920
#       Asia         57.319269
#       Europe       70.775033
#       Oceania      71.910000
# 1977  Africa       49.580423
#       Americas     64.391560
#       Asia         59.610556
#       Europe       71.937767
#       Oceania      72.855000
# 1982  Africa       51.592865
# ...

# %%
dat.groupby(["year", "continent"])[["lifeExp", "gdpPercap"]].mean()
# Out:
#                   lifeExp     gdpPercap
# year continent
# 1952 Africa     39.135500   1252.572466
#      Americas   53.279840   4079.062552
#      Asia       46.314394   5195.484004
#      Europe     64.408500   5661.057435
#      Oceania    69.255000  10298.085650
# 1957 Africa     41.266346   1385.236062
#      Americas   55.960280   4616.043733
#      Asia       49.318544   5787.732940
#      Europe     66.703067   6963.012816
#      Oceania    70.295000  11598.522455
# 1962 Africa     43.319442   1598.078825
#      Americas   58.398760   4901.541870
#      Asia       51.563223   5729.369625
#      Europe     68.539233   8365.486814
#      Oceania    71.085000  12696.452430
# 1967 Africa     45.334538   2050.363801
#      Americas   60.410920   5668.253496
#      Asia       54.663640   5971.173374
#      Europe     69.737600  10143.823757
#      Oceania    71.310000  14495.021790
# 1972 Africa     47.450942   2339.615674
#      Americas   62.394920   6491.334139
# ...

# %%
import numpy as np

# %%
dat.groupby(["year", "continent"])[["lifeExp", "gdpPercap"]].agg(["mean", np.std])
# Out:
#                   lifeExp                gdpPercap
#                      mean        std          mean           std
# year continent
# 1952 Africa     39.135500   5.151581   1252.572466    982.952116
#      Americas   53.279840   9.326082   4079.062552   3001.727522
#      Asia       46.314394   9.291751   5195.484004  18634.890865
#      Europe     64.408500   6.361088   5661.057435   3114.060493
#      Oceania    69.255000   0.190919  10298.085650    365.560078
# 1957 Africa     41.266346   5.620123   1385.236062   1134.508918
#      Americas   55.960280   9.033192   4616.043733   3312.381083
#      Asia       49.318544   9.635429   5787.732940  19506.515959
#      Europe     66.703067   5.295805   6963.012816   3677.950146
#      Oceania    70.295000   0.049497  11598.522455    917.644806
# 1962 Africa     43.319442   5.875364   1598.078825   1461.839189
#      Americas   58.398760   8.503544   4901.541870   3421.740569
# ...

# %%
(dat
 .groupby(["year", "continent"])
 [["lifeExp", "gdpPercap"]]
 .agg(["mean", np.std])
 .reset_index()
)
# Out:
#     year continent    lifeExp                gdpPercap
#                          mean        std          mean           std
# 0   1952    Africa  39.135500   5.151581   1252.572466    982.952116
# 1   1952  Americas  53.279840   9.326082   4079.062552   3001.727522
# 2   1952      Asia  46.314394   9.291751   5195.484004  18634.890865
# 3   1952    Europe  64.408500   6.361088   5661.057435   3114.060493
# 4   1952   Oceania  69.255000   0.190919  10298.085650    365.560078
# 5   1957    Africa  41.266346   5.620123   1385.236062   1134.508918
# 6   1957  Americas  55.960280   9.033192   4616.043733   3312.381083
# 7   1957      Asia  49.318544   9.635429   5787.732940  19506.515959
# 8   1957    Europe  66.703067   5.295805   6963.012816   3677.950146
# 9   1957   Oceania  70.295000   0.049497  11598.522455    917.644806
# 10  1962    Africa  43.319442   5.875364   1598.078825   1461.839189
# 11  1962  Americas  58.398760   8.503544   4901.541870   3421.740569
# ...

# %%
stats = (dat
 .groupby(["year", "continent"])
 [["lifeExp", "gdpPercap"]]
 .agg(["mean", np.std])
 .reset_index()
)

# %%
stats
# Out:
#     year continent    lifeExp                gdpPercap
#                          mean        std          mean           std
# 0   1952    Africa  39.135500   5.151581   1252.572466    982.952116
# 1   1952  Americas  53.279840   9.326082   4079.062552   3001.727522
# 2   1952      Asia  46.314394   9.291751   5195.484004  18634.890865
# 3   1952    Europe  64.408500   6.361088   5661.057435   3114.060493
# 4   1952   Oceania  69.255000   0.190919  10298.085650    365.560078
# 5   1957    Africa  41.266346   5.620123   1385.236062   1134.508918
# 6   1957  Americas  55.960280   9.033192   4616.043733   3312.381083
# 7   1957      Asia  49.318544   9.635429   5787.732940  19506.515959
# 8   1957    Europe  66.703067   5.295805   6963.012816   3677.950146
# 9   1957   Oceania  70.295000   0.049497  11598.522455    917.644806
# 10  1962    Africa  43.319442   5.875364   1598.078825   1461.839189
# 11  1962  Americas  58.398760   8.503544   4901.541870   3421.740569
# ...
